# %% [markdown]
# ### Trabalho final - Modelagem Computacional

# %% [markdown]
# #### Packages

# %%
from edo import Edo
from funcoes_trabalho_final import *
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# #### Reprodução gráfica 01 - Figura 03

# %%
metodos = ["rk4_final"]

# %%
i_app_0 = Edo(y_inicial=0, dom=800, a=0, b=8, I_app=0, I_function=calc_current_density, methods=metodos)
i_app_025 = Edo(y_inicial=0, dom=800, a=0, b=8, I_app=0.25, I_function=calc_current_density, methods=metodos)
i_app_050 = Edo(y_inicial=0, dom=800, a=0, b=8, I_app=0.5, I_function=calc_current_density, methods=metodos)
i_app_075 = Edo(y_inicial=0, dom=800, a=0, b=8, I_app=0.75, I_function=calc_current_density, methods=metodos)
i_app_1 = Edo(y_inicial=0, dom=800, a=0, b=8, I_app=1, I_function=calc_current_density, methods=metodos)

# %%
i_app_0.df_output.head()
# Out:
#    Passo  V(t) Runge-Kutta 4ª Ordem  n(t) Runge-Kutta 4ª Ordem  \
# 0   0.00                   0.000000                   0.000000
# 1   0.01                  -0.031791                   0.000581
# 2   0.02                  -0.063487                   0.001163
# 3   0.03                  -0.095088                   0.001744
# 4   0.04                  -0.126595                   0.002325
#
#    m(t) Runge-Kutta 4ª Ordem  h(t) Runge-Kutta 4ª Ordem  \
# 0                   0.000000                   0.000000
# 1                   0.002188                   0.000700
# 2                   0.004291                   0.001398
# 3                   0.006312                   0.002094
# 4                   0.008255                   0.002787
#
#    I(t) Runge-Kutta 4ª Ordem
# 0                   3.183900
# 1                   3.174363
# 2                   3.164854
# 3                   3.155374
# 4                   3.145923

# %%
i_app_025.df_output.head()
# Out:
#    Passo  V(t) Runge-Kutta 4ª Ordem  n(t) Runge-Kutta 4ª Ordem  \
# 0   0.00                   0.000000                   0.000000
# 1   0.01                  -0.029295                   0.000581
# 2   0.02                  -0.058502                   0.001162
# 3   0.03                  -0.087622                   0.001744
# 4   0.04                  -0.116655                   0.002325
#
#    m(t) Runge-Kutta 4ª Ordem  h(t) Runge-Kutta 4ª Ordem  \
# 0                   0.000000                   0.000000
# 1                   0.002188                   0.000700
# 2                   0.004291                   0.001398
# 3                   0.006311                   0.002094
# 4                   0.008253                   0.002788
#
#    I(t) Runge-Kutta 4ª Ordem
# 0                   3.183900
# 1                   3.175111
# 2                   3.166349
# 3                   3.157614
# 4                   3.148905

# %%
i_app_050.df_output.head()
# Out:
#    Passo  V(t) Runge-Kutta 4ª Ordem  n(t) Runge-Kutta 4ª Ordem  \
# 0   0.00                   0.000000                   0.000000
# 1   0.01                  -0.026799                   0.000581
# 2   0.02                  -0.053517                   0.001162
# 3   0.03                  -0.080156                   0.001743
# 4   0.04                  -0.106715                   0.002324
#
#    m(t) Runge-Kutta 4ª Ordem  h(t) Runge-Kutta 4ª Ordem  \
# 0                   0.000000                   0.000000
# 1                   0.002188                   0.000700
# 2                   0.004290                   0.001398
# 3                   0.006310                   0.002094
# 4                   0.008250                   0.002789
#
#    I(t) Runge-Kutta 4ª Ordem
# 0                   3.183900
# 1                   3.175860
# 2                   3.167845
# 3                   3.159854
# 4                   3.151887

# %%
i_app_075.df_output.head()
# Out:
#    Passo  V(t) Runge-Kutta 4ª Ordem  n(t) Runge-Kutta 4ª Ordem  \
# 0   0.00                   0.000000                   0.000000
# 1   0.01                  -0.024303                   0.000581
# 2   0.02                  -0.048532                   0.001162
# 3   0.03                  -0.072689                   0.001743
# 4   0.04                  -0.096774                   0.002324
#
#    m(t) Runge-Kutta 4ª Ordem  h(t) Runge-Kutta 4ª Ordem  \
# 0                   0.000000                   0.000000
# 1                   0.002188                   0.000700
# 2                   0.004290                   0.001398
# 3                   0.006309                   0.002094
# 4                   0.008248                   0.002789
#
#    I(t) Runge-Kutta 4ª Ordem
# 0                   3.183900
# 1                   3.176609
# 2                   3.169340
# 3                   3.162094
# 4                   3.154869

# %%
i_app_1.df_output.head()
# Out:
#    Passo  V(t) Runge-Kutta 4ª Ordem  n(t) Runge-Kutta 4ª Ordem  \
# 0   0.00                   0.000000                   0.000000
# 1   0.01                  -0.021806                   0.000581
# 2   0.02                  -0.043547                   0.001162
# 3   0.03                  -0.065223                   0.001743
# 4   0.04                  -0.086834                   0.002323
#
#    m(t) Runge-Kutta 4ª Ordem  h(t) Runge-Kutta 4ª Ordem  \
# 0                   0.000000                   0.000000
# 1                   0.002188                   0.000700
# 2                   0.004290                   0.001398
# 3                   0.006307                   0.002095
# 4                   0.008246                   0.002790
#
#    I(t) Runge-Kutta 4ª Ordem
# 0                   3.183900
# 1                   3.177358
# 2                   3.170836
# 3                   3.164334
# 4                   3.157851

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_output(variable="V", title="V(t)", dfs=dfs)

# %%
plot_output(variable="m", title="m(t)", dfs=dfs)

# %%
plot_output(variable="n", title="n(t)", dfs=dfs)

# %%
plot_output(variable="h", title="h(t)", dfs=dfs)

# %%
plot_output(variable="I", title="I(t)", dfs=dfs)
