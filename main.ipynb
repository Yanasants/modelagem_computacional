# %% [markdown]
# ### Trabalho final - Modelagem Computacional

# %% [markdown]
# #### Packages

# %%
from edo import Edo
from funcoes_trabalho_final import *
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# #### Reprodução gráfica 01 - Figura 03

# %%
metodos = ["rk4_final"]

# %%
y_inicial, dom, a, b, I_function = 0, 800, 0, 8, calc_current_density
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=0, I_function=I_function, methods=metodos)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=0.25, I_function=I_function, methods=metodos)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=0.5, I_function=I_function, methods=metodos)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=0.75, I_function=I_function, methods=metodos)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=1, I_function=I_function, methods=metodos)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_output(variable="I", title="Densidade de corrente (uA/cm^2)", dfs=dfs)

# %%
y_inicial, dom, a, b, I_function = 0.4, 1200, 0, 12, calc_current_density
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=0, I_function=I_function, methods=metodos)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=0.25, I_function=I_function, methods=metodos)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=0.5, I_function=I_function, methods=metodos)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=0.75, I_function=I_function, methods=metodos)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, I_app=1, I_function=I_function, methods=metodos)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_output(variable="n", title="Proporção de íons K+ no interior da célula", dfs=dfs)
