# %% [markdown]
# ### Trabalho final - Modelagem Computacional

# %% [markdown]
# #### Packages

# %%
from edo import Edo
from funcoes_trabalho_final import *
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# #### Reprodução gráfica 01 - Figura 03

# %%
metodos = ["rk4_final"]

# %% [markdown]
# ##### Com alfa e beta variáveis

# %%
y_inicial, dom, a, b, I_function = 0, 800, 0, 8, calc_current_density
v0, n0, m0, h0 = -60, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_output(variable="I", title="Densidade de corrente (uA/cm^2)", dfs=dfs)

# %% [markdown]
# ##### Sem alfa e beta variáveis

# %%
y_inicial, dom, a, b, I_function = 0, 800, 0, 8, calc_current_density
v0, n0, m0, h0 = -60, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos, fixo=True)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos, fixo=True)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos, fixo=True)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos, fixo=True)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos, fixo=True)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_output(variable="I", title="Densidade de corrente (uA/cm^2)", dfs=dfs)

# %% [markdown]
# #### Resolução gráfico 02

# %% [markdown]
# ##### Com alfa e beta variáveis

# %%
y_inicial, dom, a, b, I_function = 0, 1200, 0, 12, calc_current_density
v0, n0, m0, h0 = 0, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_output(variable="n", title="Proporção de íons K+ no interior da célula", dfs=dfs)

# %% [markdown]
# ##### Sem alfa e beta variáveis

# %%
y_inicial, dom, a, b, I_function = 0, 1200, 0, 12, calc_current_density
v0, n0, m0, h0 = 0, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos, fixo=True)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos, fixo=True)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos, fixo=True)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos, fixo=True)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos, fixo=True)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_output(variable="n", title="Proporção de íons K+ no interior da célula", dfs=dfs)

# %% [markdown]
# #### Resolução gráfico 03

# %% [markdown]
# ##### Com alfa e beta variáveis

# %%
y_inicial, dom, a, b, I_function = 0, 1200, 0, 12, calc_current_density
v0, n0, m0, h0 = -63, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_condutancias(variable="gk", dfs=dfs)

# %% [markdown]
# ##### Sem alfa e beta variáveis

# %%
y_inicial, dom, a, b, I_function = 0, 1200, 0, 12, calc_current_density
v0, n0, m0, h0 = -63, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos, fixo=True)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos, fixo=True)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos, fixo=True)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos, fixo=True)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos, fixo=True)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_condutancias(variable="gk", dfs=dfs)

# %% [markdown]
# #### Reprodução gráfico 04

# %% [markdown]
# ##### Com alfa e beta variáveis

# %%
y_inicial, dom, a, b, I_function = 0, 1200, 0, 12, calc_current_density
v0, n0, m0, h0 = -109, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_condutancias(variable="gk", dfs=dfs)

# %% [markdown]
# ##### Sem alfa e beta variáveis

# %%
y_inicial, dom, a, b, I_function = 0, 1200, 0, 12, calc_current_density
v0, n0, m0, h0 = -109, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos, fixo=True)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos, fixo=True)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos, fixo=True)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos, fixo=True)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos, fixo=True)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_condutancias(variable="gk", dfs=dfs)

# %% [markdown]
# #### Reprodução gráfico 05

# %%
y_inicial, dom, a, b, I_function = 0, 1200, 0, 12, calc_current_density
v0, n0, m0, h0 = -63, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_condutancias(variable="gna", dfs=dfs)

# %% [markdown]
# #### Reprodução gráfico 06

# %%
y_inicial, dom, a, b, I_function = 0, 1200, 0, 12, calc_current_density
v0, n0, m0, h0 = -109, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos)

# %%
dfs = {"I_app 0": i_app_0, "I_app 0.25": i_app_025, "I_app 0.50": i_app_050, "I_app 0.75": i_app_075, "I_app 1": i_app_1}

# %%
plot_condutancias(variable="gna", dfs=dfs)

# %% [markdown]
# #### Reprodução gráfico 07

# %%
y_inicial, dom, a, b, I_function = 0, 800, 0, 8, calc_current_density
v0, n0, m0, h0 = -60, 0, 0, 0
i_app_0 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0, I_function=I_function, methods=metodos, fixo=True)
i_app_025 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.25, I_function=I_function, methods=metodos, fixo=True)
i_app_050 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.5, I_function=I_function, methods=metodos, fixo=True)
i_app_075 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=0.75, I_function=I_function, methods=metodos, fixo=True)
i_app_1 = Edo(y_inicial=y_inicial, dom=dom, a=a, b=b, v0=v0, n0=n0, m0=m0, h0=h0, I_app=1, I_function=I_function, methods=metodos, fixo=True)
