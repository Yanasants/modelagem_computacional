# %% [markdown]
# ### L2: Modelagem Computacional

# %%
from edo_lista_2 import Edo
from funcoes_lista_2 import *

# %% [markdown]
# #### Questão 01

# %%
metodos = ['euller',"euller_implicito",'rk4']

# %%
e = Edo(y_inicial=0.75, dom=300, a=0, b=6, \
        f_function=funcao_1, methods=metodos, \
        analytic_solution=True, analytic_function=analitica_1, bidimensional=False)

# %%
e.df_output.head()
# Out:
#    Passo  Yt_Euller  Yt_Euller_Implicito    Yt_RK4  Yt_Analitica
# 0   0.00   0.750000             0.750000  0.750000      0.750000
# 1   0.02   0.702000             0.954865  0.954834      0.004482
# 2   0.04   1.159729             1.618587  1.603443      0.255670
# 3   0.06   2.029445             2.653740  2.612295      0.947505
# 4   0.08   3.230036             3.984708  3.908993      1.996680

# %%
e.plot_output()

# %% [markdown]
# #### Questão 02

# %%
metodos = ['euller','rk4']

# %% [markdown]
# ##### a)

# %%
e = Edo(y_inicial=(0,12), dom=300, a=0, b=16, \
        f_function=funcao_2_a, methods=metodos, \
        analytic_solution=False, bidimensional=True)

# %%
e.df_output
# Out:
#          Passo    Xt_Euller  Yt_Euller       Xt_RK4     Yt_RK4
# 0     0.000000     0.000000  12.000000     0.000000  12.000000
# 1     0.053333     0.000000  11.488000    -0.002288  11.501013
# 2     0.106667    -0.004551  11.002396    -0.009200  11.027323
# 3     0.160000    -0.013726  10.542063    -0.020812  10.577874
# 4     0.213333    -0.027599  10.105922    -0.037198  10.151654
# ..         ...          ...        ...          ...        ...
# 295  15.733333 -1819.284364  28.966704 -1892.413376  28.966716
# 296  15.786667 -1849.735491  29.073369 -1924.291179  29.073381
# 297  15.840000 -1880.678388  29.180034 -1956.687718  29.180045
# 298  15.893333 -1912.120922  29.286700 -1989.611357  29.286710
# 299  15.946667 -1944.071088  29.393365 -2023.070600  29.393375
#
# [300 rows x 5 columns]

# %%
e.plot_output()

# %% [markdown]
# ##### b)
