# %% [markdown]
# ### L2: Modelagem Computacional

# %%
from edo_lista_2 import Edo
from funcoes_lista_2 import *

# %% [markdown]
# #### Questão 01

# %%
metodos = ['euller',"euller_implicito",'rk4']

# %%
e = Edo(y_inicial=0.75, dom=300, a=0, b=6, \
        f_function=funcao_1, methods=metodos, \
        analytic_solution=True, analytic_function=analitica_1, bidimensional=False)

# %%
e.df_output.head()
# Out:
#    Passo  Y(t) Euller  Y(t) Euller Implícito  Y(t) Runge-Kutta 4ª Ordem  \
# 0   0.00     0.750000               0.750000                   0.750000
# 1   0.02     0.702000               0.954865                   0.954834
# 2   0.04     1.159729               1.618587                   1.603443
# 3   0.06     2.029445               2.653740                   2.612295
# 4   0.08     3.230036               3.984708                   3.908993
#
#    Y(t) Analítica
# 0        0.750000
# 1        0.004482
# 2        0.255670
# 3        0.947505
# 4        1.996680

# %%
e.plot_output()

# %% [markdown]
# #### Questão 02

# %%
metodos = ['euller','rk4']

# %% [markdown]
# ##### a)

# %%
e = Edo(y_inicial=(0,12), dom=80, a=0, b=16, \
        f_function=funcao_2_a, methods=metodos, \
        analytic_solution=False, bidimensional=True)

# %%
e.df_output.head()
# Out:
#    Passo  X(t) Euller  Y(t) Euller  X(t) Runge-Kutta 4ª Ordem  \
# 0    0.0      0.00000    12.000000                   0.000000
# 1    0.2      0.00000    10.080000                  -0.032650
# 2    0.4     -0.06400     8.531200                  -0.133277
# 3    0.6     -0.19584     7.294208                  -0.306086
# 4    0.8     -0.39959     6.319135                  -0.555540
#
#    Y(t) Runge-Kutta 4ª Ordem
# 0                  12.000000
# 1                  10.256097
# 2                   8.829182
# 3                   7.672386
# 4                   6.745771

# %%
e.plot_output()

# %% [markdown]
# ##### b)

# %%
e = Edo(y_inicial=(20, 40, 60), dom=200, a=0, b=20, \
        f_function=funcao_2_b, methods=metodos, \
        analytic_solution=True, analytic_function=analitica_2_b, tridimensional=True)

# %%
e.df_output.head()
# Out:
#    Passo  X(t) Euller  Y(t) Euller  Z(t) Euller  X(t) Runge-Kutta 4ª Ordem  \
# 0    0.0    20.000000    40.000000    60.000000                  20.000000
# 1    0.1    19.000000    40.000000    60.000000                  19.024589
# 2    0.2    18.050000    39.950000    60.000000                  18.096748
# 3    0.3    17.147500    39.853750    59.998750                  17.214160
# 4    0.4    16.290125    39.714781    59.995115                  16.374615
#
#    Y(t) Runge-Kutta 4ª Ordem  Z(t) Runge-Kutta 4ª Ordem  X(t) Analítica  \
# 0                  40.000000                  60.000000       20.000000
# 1                  39.975616                  59.999796       20.000000
# 2                  39.904857                  59.998408       19.024588
# 3                  39.791160                  59.994747       18.096748
# 4                  39.637763                  59.987828       17.214160
#
#    Y(t) Analítica  Z(t) Analítica
# 0       40.000000       60.000000
# ...

# %%
e.plot_output()

# %% [markdown]
# ##### c)

# %%
e = Edo(y_inicial=(60, 30, 60), dom=40, a=0, b=20, \
        f_function=funcao_2_c, methods=metodos, \
        analytic_solution=True, analytic_function=analitica_3_c, tridimensional=True)

# %%
e.df_output.head()
# Out:
#    Passo  X(t) Euller  Y(t) Euller  Z(t) Euller  X(t) Runge-Kutta 4ª Ordem  \
# 0    0.0         60.0         30.0         60.0                       60.0
# 1    0.5         60.0         30.0         60.0                       60.0
# 2    1.0         60.0         30.0         60.0                       60.0
# 3    1.5         60.0         30.0         60.0                       60.0
# 4    2.0         60.0         30.0         60.0                       60.0
#
#    Y(t) Runge-Kutta 4ª Ordem  Z(t) Runge-Kutta 4ª Ordem  X(t) Analítica  \
# 0                       30.0                       60.0       60.000000
# 1                       30.0                       60.0      210.000000
# 2                       30.0                       60.0      595.936181
# 3                       30.0                       60.0     1892.016278
# 4                       30.0                       60.0     4777.857303
#
#    Y(t) Analítica  Z(t) Analítica
# 0       30.000000            60.0
# ...

# %%
e.plot_output()
