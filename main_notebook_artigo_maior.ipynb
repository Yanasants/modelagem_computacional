# %% [markdown]
# #### Mathematical analysis with numerical solutions of the mathematical model for the complications and control of diabetes mellitus

# %%
from edo_artigo import Edo
from funcoes_artigo_maior import *

import numpy as np

# %% [markdown]
# #### Reprodução dos resultados

# %%
e_1 = Edo(y_inicial=(90210290.2097902, 155769730.76923075), \
            dom=200, a=0, b=100, \
            f_function=equations_system, \
            analytic_solution=True, \
            analytic_function=analitica, \
            bidimensional=True)

# %%
e_1.df_output
# Out:
#      Passo     Ct_Euller     Nt_Euller        Ct_RK4        Nt_RK4  \
# 0      0.0  9.021029e+07  1.557697e+08  9.021029e+07  1.557697e+08
# 1      0.5  9.310786e+07  1.557015e+08  9.223796e+07  1.556444e+08
# 2      1.0  9.384673e+07  1.554891e+08  9.316238e+07  1.554505e+08
# 3      1.5  9.395226e+07  1.552419e+08  9.354314e+07  1.552277e+08
# 4      2.0  9.387515e+07  1.549919e+08  9.365748e+07  1.549958e+08
# ..     ...           ...           ...           ...           ...
# 195   97.5  9.021114e+07  1.489533e+08  9.021138e+07  1.489536e+08
# 196   98.0  9.021108e+07  1.489532e+08  9.021132e+07  1.489535e+08
# 197   98.5  9.021103e+07  1.489531e+08  9.021126e+07  1.489534e+08
# 198   99.0  9.021098e+07  1.489530e+08  9.021120e+07  1.489533e+08
# 199   99.5  9.021093e+07  1.489529e+08  9.021114e+07  1.489533e+08
#
#      Ct_Analitica  Nt_Analitica
# 0    9.021029e+07  1.557697e+08
# 1    9.021029e+07  1.557697e+08
# 2    9.224360e+07  1.556448e+08
# ...

# %%
e_1.plot_output(variable="C")

# %%
e_1.plot_output(variable="N")
